# %%
import pandas as pd
import twint
import nest_asyncio
import re
import csv
import random
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import nltk
import warnings
import json
import pickle
warnings.filterwarnings("ignore",category=DeprecationWarning)
# %matplotlib inline

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter
from string import punctuation
from wordcloud import WordCloud

# %%
data = pd.read_csv('train.csv')

# %%
data
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
# [27481 rows x 4 columns]

# %%
positives = data['sentiment'][data.sentiment == 'positive' ]
negatives = data['sentiment'][data.sentiment == 'negative']

print('number of positve tagged sentences is:  {}'.format(len(positives)))
print('number of negative tagged sentences is: {}'.format(len(negatives)))
print('total length of the data is:            {}'.format(data.shape[0]))
# Out:
# number of positve tagged sentences is:  8582
# number of negative tagged sentences is: 7781
# total length of the data is:            27481

# %%
data['label']=data['sentiment'].apply(lambda x:1 if x=="positive" else(-1 if x=="negative" else 0))

# %%
data.dtypes
# Out:
# textID           object
# text             object
# selected_text    object
# sentiment        object
# label             int64
# dtype: object

# %%
col_name="label"
first_col = data.pop(col_name)

# %%
data.insert(0, "label", first_col)

# %%
data = data[['label','selected_text']]

# %%
is_NaN = data.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = data[row_has_NaN]

print(rows_with_NaN)
# Out:
#      label selected_text
# 314      0           NaN

# %%
data = data.drop(314)

# %%
data.head()
# Out:
#    label                        selected_text
# 0      0  I`d have responded, if I were going
# 1     -1                             Sooo SAD
# 2     -1                          bullying me
# 3     -1                       leave me alone
# 4     -1                        Sons of ****,

# %%
# Run Train Data Through Pipeline analyzer=text_process
# uncomment below to train on a larger dataset but it is very slow for a regular laptop

X_train, X_test, y_train, y_test = train_test_split(data['selected_text'], data['label'], test_size=0.2)
#X_train, X_test, y_train, y_test = train_test_split(data['selected_text'][:5000], data['label'][:5000], test_size=0.2)


# create pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(strip_accents='ascii',
                            stop_words='english',
                            lowercase=True)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# this is where we define the values for GridSearchCV to iterate over
parameters = {'bow__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'classifier__alpha': (1e-2, 1e-3),
             }

# do 10-fold cross validation for each of the 6 possible combinations of the above params
grid = GridSearchCV(pipeline, cv=10, param_grid=parameters, verbose=1)
grid.fit(X_train,y_train)

# summarize results
print("\nBest Model: %f using %s" % (grid.best_score_, grid.best_params_))
print('\n')
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
params = grid.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean: %f Stdev:(%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  1.5min finished
# Best Model: 0.775382 using {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
#
#
# Mean: 0.767194 Stdev:(0.009795) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.774472 Stdev:(0.008640) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.765511 Stdev:(0.008884) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.771106 Stdev:(0.008359) with: {'bow__ngram_range': (1, 1), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}
# Mean: 0.765648 Stdev:(0.009400) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': True}
# Mean: 0.775382 Stdev:(0.008965) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.01, 'tfidf__use_idf': False}
# Mean: 0.762054 Stdev:(0.009469) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': True}
# Mean: 0.769332 Stdev:(0.009354) with: {'bow__ngram_range': (1, 2), 'classifier__alpha': 0.001, 'tfidf__use_idf': False}

# %%
# save best model to current working directory
joblib.dump(grid, "twitter_sentiment.pkl")
# Out:
# ['twitter_sentiment.pkl']

# %%
model_NB = joblib.load("twitter_sentiment.pkl" )

# get predictions from best model above
y_preds = model_NB.predict(X_test)

print('accuracy score: ',accuracy_score(y_test, y_preds))
print('\n')
print('confusion matrix: \n',confusion_matrix(y_test,y_preds))
print('\n')
print(classification_report(y_test, y_preds))
# Out:
# accuracy score:  0.7787481804949054
#
#
# confusion matrix:
#  [[1049  460   82]
#  [ 159 1912  160]
#  [  57  298 1319]]
#
#
#               precision    recall  f1-score   support
#
#           -1       0.83      0.66      0.73      1591
#            0       0.72      0.86      0.78      2231
#            1       0.84      0.79      0.82      1674
#
#     accuracy                           0.78      5496
#    macro avg       0.80      0.77      0.78      5496
# weighted avg       0.79      0.78      0.78      5496

# %%
tweet = pd.read_csv('Lockdown1.0.csv',encoding= 'latin1')

# %%
tweet.to_pickle('df_lockdown.p')

# %%
df_lockdown = pd.read_pickle('df_lockdown.p')

# %%
def processTweet(tweet):
    # Remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;', '', tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # Remove tickers
    tweet = re.sub(r'\$\w*', '', tweet)
    # To lowercase
    tweet = tweet.lower()
    # Remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    # Remove hashtags
    tweet = re.sub(r'#\w*', '', tweet)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet)
    # Remove words with 2 or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b', '', tweet)
    # Remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # Remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet
# ______________________________________________________________

# clean dataframe's text column
df_lockdown['tweet'] = df_lockdown['tweet'].apply(processTweet)
# preview some cleaned tweets
df_lockdown['tweet'].head()
# Out:
# 0    the jio company launched their new plans calle...
# 1    reliance jio offers free internet airtel voda ...
# 2        yes home only you can work from home you are
# 3    apart from the jokes you may you need anyone t...
# 4                                      work from home
# Name: tweet, dtype: object

# %%
#Remove terms like word-word
before = df_lockdown['tweet'][100]
after = processTweet(before)

before,'\n',after
# Out:
# ('let sonia gandhi rahul gandhi and robert vadra start distributing their accumulated wealth poor people charity begins from home why can start helping poor people one banglow occupied this family spared isolation ward for covid patients convey them \x80¦',
#  '\n',
#  'let sonia gandhi rahul gandhi and robert vadra start distributing their accumulated wealth poor people charity begins from home why can start helping poor people one banglow occupied this family spared isolation ward for covid patients convey them \x80¦')

# %%
all_words = []
for line in list(df_lockdown['tweet']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())

# plot word frequency distribution of first few words
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)

# log-log of all words 
word_counts = sorted(Counter(all_words).values(), reverse=True)

plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# C:\Users\Bhushan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Bhushan\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Text(0.5, 0, 'Word Rank')

# %%
df_lockdown = df_lockdown.drop_duplicates('tweet')
df_lockdown.shape
# Out:
# (3515, 34)

# %%
# show stop words examples
nltk.download('stopwords')
stop_words = stopwords.words('english') # Show some stop words
' , '.join(stop_words)[:200], len(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bhushan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ("i , me , my , myself , we , our , ours , ourselves , you , you're , you've , you'll , you'd , your , yours , yourself , yourselves , he , him , his , himself , she , she's , her , hers , herself , it ",
#  179)

# %%
df_lockdown.head()
# Out:
#    Unnamed: 0                   id      conversation_id     created_at  \
# 0           0  1242879759601799168  1242745110661435393  1585160600000
# 1           1  1242879607176478720  1242879607176478720  1585160564000
# 2           2  1242879202866515969  1242450477779800065  1585160468000
# 3           3  1242878275585802240  1242873807137726464  1585160247000
# 4           4  1242876746459803658  1242717249590321157  1585159882000
#
#                   date  timezone place  \
# 0  2020-03-25 23:53:20       530   NaN
# 1  2020-03-25 23:52:44       530   NaN
# 2  2020-03-25 23:51:08       530   NaN
# 3  2020-03-25 23:47:27       530   NaN
# 4  2020-03-25 23:41:22       530   NaN
#
#                                                tweet hashtags cashtags  ...  \
# 0  the jio company launched their new plans calle...       []       []  ...
# 1  reliance jio offers free internet airtel voda ...       []       []  ...
# 2      yes home only you can work from home you are        []       []  ...
# 3  apart from the jokes you may you need anyone t...       []       []  ...
# 4                                    work from home        []       []  ...
#
#                       geo  source user_rt_id user_rt  retweet_id  \
# 0  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 1  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 2  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 3  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
# 4  28.5934,77.2223,2000km     NaN        NaN     NaN         NaN
#
#                                             reply_to retweet_date  translate  \
# 0  [{'user_id': '853512722113323008', 'username':...          NaN        NaN
# 1  [{'user_id': '869018357432950785', 'username':...          NaN        NaN
# 2  [{'user_id': '804045415322554368', 'username':...          NaN        NaN
# 3  [{'user_id': '714465124782768128', 'username':...          NaN        NaN
# 4  [{'user_id': '276394575', 'username': 'hiren_r...          NaN        NaN
#
#    trans_src  trans_dest
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
#
# [5 rows x 34 columns]

# %%
# tokenize helper function
def text_process(raw_text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stopwords.words('english')]
df_lockdown = df_lockdown.copy()
df_lockdown['tokens'] = df_lockdown['tweet'].apply(text_process) # tokenize style 1

# %%
df_lockdown.head()
# Out:
#    Unnamed: 0                   id      conversation_id     created_at  \
# 0           0  1242879759601799168  1242745110661435393  1585160600000
# 1           1  1242879607176478720  1242879607176478720  1585160564000
# 2           2  1242879202866515969  1242450477779800065  1585160468000
# 3           3  1242878275585802240  1242873807137726464  1585160247000
# 4           4  1242876746459803658  1242717249590321157  1585159882000
#
#                   date  timezone place  \
# 0  2020-03-25 23:53:20       530   NaN
# 1  2020-03-25 23:52:44       530   NaN
# 2  2020-03-25 23:51:08       530   NaN
# 3  2020-03-25 23:47:27       530   NaN
# 4  2020-03-25 23:41:22       530   NaN
#
#                                                tweet hashtags cashtags  ...  \
# 0  the jio company launched their new plans calle...       []       []  ...
# 1  reliance jio offers free internet airtel voda ...       []       []  ...
# 2      yes home only you can work from home you are        []       []  ...
# 3  apart from the jokes you may you need anyone t...       []       []  ...
# 4                                    work from home        []       []  ...
#
#    source  user_rt_id user_rt retweet_id  \
# 0     NaN         NaN     NaN        NaN
# 1     NaN         NaN     NaN        NaN
# 2     NaN         NaN     NaN        NaN
# 3     NaN         NaN     NaN        NaN
# 4     NaN         NaN     NaN        NaN
#
#                                             reply_to  retweet_date translate  \
# 0  [{'user_id': '853512722113323008', 'username':...           NaN       NaN
# 1  [{'user_id': '869018357432950785', 'username':...           NaN       NaN
# 2  [{'user_id': '804045415322554368', 'username':...           NaN       NaN
# 3  [{'user_id': '714465124782768128', 'username':...           NaN       NaN
# 4  [{'user_id': '276394575', 'username': 'hiren_r...           NaN       NaN
#
#    trans_src  trans_dest                                             tokens
# 0        NaN         NaN  [jio, company, launched, new, plans, called, w...
# 1        NaN         NaN  [reliance, jio, offers, free, internet, airtel...
# 2        NaN         NaN                            [yes, home, work, home]
# 3        NaN         NaN  [apart, jokes, may, need, anyone, talk, away, ...
# 4        NaN         NaN                                       [work, home]
#
# [5 rows x 35 columns]

# %%
# vetorize
bow_transformer = CountVectorizer(analyzer=text_process).fit(df_lockdown['tweet'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 11870

# %%
bow_transformer.vocabulary_
# Out:
# {'jio': 5415,
#  'company': 2490,
#  'launched': 5871,
#  'new': 6928,
#  'plans': 7634,
#  'called': 2062,
#  'work': 10924,
#  'home': 4752,
#  'reliance': 8364,
#  'offers': 7139,
#  'free': 4135,
#  'internet': 5228,
#  'airtel': 1031,
#  'voda': 10645,
#  'idea': 4949,
#  'promise': 7931,
#  'normal': 7020,
#  'needs': 6886,
#  '\x80¦': 11262,
#  'yes': 11078,
#  'apart': 1208,
#  'jokes': 5450,
#  'may': 6383,
#  'need': 6881,
#  'anyone': 1201,
#  'talk': 9753,
#  'away': 1446,
#  'lockdown': 6049,
#  'know': 5711,
#  'feels': 3938,
#  'like': 5979,
#  'hell': 4667,
#  'comforting': 2457,
#  'way': 10759,
#  'helpful': 4672,
#  'gladâ\x9d¤¸\x8f': 4345,
#  'time': 10007,
#  'protect': 7947,
#  'covid': 2735,
#  'stage': 9407,
#  'people': 7502,
#  'stay': 9449,
#  'best': 1711,
#  'cure': 2816,
#  'question': 8094,
#  'economy': 3492,
#  'staving': 9448,
#  'mine': 6524,
#  'putting': 8032,
#  'kapoor': 5540,
#  'kanika': 5531,
#  'rana': 8183,
#  'different': 3185,
#  'corners': 2681,
#  'gives': 4340,
#  'fragrant': 4130,
#  'calmness': 2070,
#  'cheezein': 2267,
#  'nahi': 6781,
#  'mil': 6502,
#  'rahi': 8136,
#  'wohiii': 10911,
#  'khatam': 5636,
#  'hai': 4542,
#  'gai': 4227,
#  'working': 10931,
#  'tough': 10084,
#  'prevent': 7851,
#  'coming': 2461,
#  'local': 6039,
#  'nagar': 6776,
#  'nigam': 6955,
#  'workers': 10928,
#  'distributed': 3279,
#  'essential': 3690,
#  'things': 9943,
#  'collect': 2434,
#  'money': 6625,
#  'door': 3354,
#  'daily': 2873,
#  'worker': 10926,
#  'get': 4297,
#  'income': 5055,
#  'quarantine': 8079,
#  'hope': 4809,
#  'see': 8924,
#  'suggestion': 9600,
#  'thanks': 9910,
#  '\x80\x93': 11190,
#  'shivalik': 9079,
#  'haridwar': 4597,
#  'put': 8029,
#  'stamp': 9412,
#  'hands': 4569,
#  'take': 9746,
#  'aadhaar': 787,
#  'pan': 7363,
#  'bank': 1570,
#  'details': 3095,
#  'later': 5861,
#  'check': 2257,
#  'health': 4640,
#  'every': 3714,
#  'week': 10789,
#  'stop': 9487,
#  'spread': 9376,
#  'hyderabad': 4916,
#  'state': 9433,
#  '60000': 582,
#  'airtravellers': 1032,
#  'still': 9475,
#  'tested': 9878,
#  'escaped': 3682,
#  'proper': 7939,
#  'checks': 2263,
#  'want': 10721,
#  'ask': 1329,
#  'thereâ\x80\x99': 9927,
#  'corresponding': 2696,
#  'fine': 3989,
#  'companies': 2488,
#  'donâ\x80\x99': 3350,
#  'comply': 2520,
#  'regulations': 8332,
#  'mohalla': 6606,
#  'clinic': 2381,
#  'doctor': 3322,
#  'mohanpuri': 6610,
#  'maujpur': 6378,
#  'area': 1271,
#  'gopal': 4385,
#  'jha': 5401,
#  'found': 4116,
#  'request': 8432,
#  'visited': 10623,
#  '12th': 100,
#  'march': 6314,
#  '18th': 166,
#  'follow': 4071,
#  'days': 2912,
#  'pic': 7584,
#  'twitter': 10230,
#  'com': 2448,
#  'xouum13ekv': 11029,
#  'revoke': 8540,
#  'article': 1304,
#  '370': 438,
#  'become': 1648,
#  'silent': 9149,
#  'shutdown': 9121,
#  'services': 8990,
#  'due': 3422,
#  'security': 8923,
#  'purposes': 8020,
#  'whole': 10842,
#  'world': 10947,
#  'global': 4348,
#  'emergency': 3561,
#  'everyone': 3717,
#  'restored': 8498,
#  'aspirants': 1334,
#  'suffering': 9593,
#  'bad': 1500,
#  'connection': 2574,
#  'service': 8989,
#  'please': 7656,
#  'make': 6233,
#  'worthy': 10961,
#  'trust': 10192,
#  'recharge': 8265,
#  'plan': 7627,
#  'cannot': 2087,
#  'use': 10416,
#  'network': 6922,
#  'good': 4378,
#  'first': 4003,
#  'leave': 5907,
#  'office': 7140,
#  'option': 7239,
#  'ourself': 7281,
#  'show': 9102,
#  'mental': 6446,
#  'toughness': 10085,
#  'pass': 7427,
#  'crucial': 2786,
#  'phase': 7558,
#  'bhi': 1742,
#  'vha': 10558,
#  'tweet': 10224,
#  'kero': 5607,
#  'open': 7210,
#  'nhi': 6950,
#  'skta': 9209,
#  'wow': 10964,
#  'video': 10569,
#  'suggest': 9597,
#  'corona': 2682,
#  'asked': 1330,
#  'permission': 7524,
#  'enter': 3639,
#  'india': 5073,
#  'info': 5123,
#  'export': 3801,
#  'stopped': 9488,
#  'jan': 5372,
#  'half': 4553,
#  'knowledge': 5713,
#  'dangerous': 2887,
#  'many': 6305,
#  'fed': 3928,
#  'day': 2910,
#  'feed': 3931,
#  'much': 6704,
#  'next': 6937,
#  '3wk': 466,
#  'strt': 9534,
#  'frm': 4159,
#  'jazz': 5392,
#  'legend': 5915,
#  'manu': 6299,
#  'dibango': 3165,
#  'died': 3176,
#  'paris': 7397,
#  'aged': 982,
#  'catching': 2142,
#  'coronavirus': 2685,
#  'known': 5715,
#  '1972': 175,
#  'song': 9293,
#  'soul': 9310,
#  'makossa': 6237,
#  'often': 7154,
#  'fused': 4201,
#  'funk': 4196,
#  'music': 6733,
#  'traditional': 10113,
#  'sounds': 9313,
#  'country': 2716,
#  'ofâ\x80¦': 7156,
#  'igshid': 4972,
#  '1fusp1s3k3uz5â': 221,
#  'ghordi': 4313,
#  'highly': 4701,
#  'populated': 7726,
#  'back': 1493,
#  'outside': 7295,
#  'humbly': 4893,
#  'jitender': 5421,
#  'singh': 9170,
#  'kindly': 5676,
#  'centre': 2170,
#  'depute': 3063,
#  'incharge': 5047,
#  'officers': 7143,
#  'along': 1089,
#  'consider': 2582,
#  'sirð\x9f\x99\x8f': 9184,
#  'wishav': 10883,
#  'dev': 3103,
#  'president': 7841,
#  'block': 1809,
#  'indoor': 5092,
#  'safe': 8720,
#  'spidey': 9357,
#  'environmental': 3652,
#  'challenges': 2211,
#  'lets': 5937,
#  'healthy': 4643,
#  'vanish': 10500,
#  'pandemic': 7368,
#  'disease': 3244,
#  'shot': 9095,
#  'onâ\x80¦': 7205,
#  '1lejmlzf47rm4â': 255,
#  'finally': 3982,
#  'carelessness': 2115,
#  'gone': 4375,
#  'wiseness': 10881,
#  'high': 4695,
#  'keep': 5591,
#  'loved': 6101,
#  'ones': 7192,
#  'situation': 9195,
#  'washing': 10743,
#  'least': 5906,
#  'metres': 6470,
#  'meet': 6425,
#  '\x9f\x99\x8f\x9f\x8f': 11632,
#  'sending': 8957,
#  '\x9f\x92\x95hope': 11457,
#  'lhhudsvdqo': 5955,
#  'protective': 7951,
#  'virus': 10612,
#  'wash': 10741,
#  'hand': 4562,
#  'cover': 2729,
#  'mouth': 6669,
#  'nose': 7024,
#  'mask': 6352,
#  'golves': 4373,
#  'tb8edjz2hr': 9796,
#  'announced': 1172,
#  'paid': 7342,
#  'holidays': 4750,
#  'possible': 7743,
#  'employees': 3575,
#  'everytime': 3722,
#  'think': 9945,
#  'would': 10962,
#  'hathway': 4613,
#  'always': 1104,
#  'disappointed': 3217,
#  'everyday': 3716,
#  'disconnected': 3228,
#  'person': 7533,
#  'kind': 5673,
#  'broadband': 1952,
#  'skmbrah3pf': 9208,
#  'sector': 8917,
#  'noida': 7004,
#  'wonder': 10914,
#  'shutting': 9124,
#  'clearly': 2373,
#  'worst': 10957,
#  'ever': 3713,
#  'someone': 9281,
#  'type': 10239,
#  'speed': 9345,
#  'yrjg240z5g': 11109,
#  'call': 2061,
#  'dubai': 3419,
#  'private': 7877,
#  'must': 6741,
#  '997340â': 748,
#  'via': 10561,
#  '5f26eqf4wr': 559,
#  'four': 4119,
#  'cases': 2133,
#  'bandipora': 1553,
#  'positive': 7738,
#  'save': 8832,
#  'lives': 6025,
#  'one': 7191,
#  'seem': 8930,
#  'find': 3986,
#  'balance': 1530,
#  'anand': 1143,
#  'vallabh': 10491,
#  'vidyanagar': 10575,
#  'awesome': 1449,
#  'welcoming': 10804,
#  '\x9d¤': 11345,
#  'post': 7744,
#  'gujarat': 4491,
#  'tour': 10086,
#  'nov': 7040,
#  'dec': 2937,
#  '2019': 329,
#  'suggesting': 9599,
#  'folks': 4070,
#  '5wdopr6y23': 580,
#  'range': 8190,
#  'options': 7241,
#  'choose': 2316,
#  'let': 5936,
#  'ensure': 3636,
#  'together': 10047,
#  '175': 150,
#  'far': 3883,
#  'labourer': 5804,
#  'antresh': 1192,
#  'village': 10589,
#  'delhi': 3006,
#  'walking': 10716,
#  'wages': 10698,
#  'food': 4078,
#  'public': 7989,
#  'transport': 10136,
#  'done': 3346,
#  'vulnerable': 10676,
#  'cfpgv5ueax': 2185,
#  'struggling': 9540,
#  'activities': 890,
#  'thoda': 9957,
#  'aap': 801,
#  'kuch': 5761,
#  '\x9f\x99\x8f\x9f\x99\x8f\x9f\x99\x8f': 11651,
#  'sucks': 9585,
#  '9xgbaif2bj': 772,
#  'understand': 10306,
#  'cause': 2147,
#  'right': 8568,
#  'using': 10425,
#  'able': 824,
#  'believe': 1683,
#  'provide': 7963,
#  'hey': 4687,
#  'card': 2106,
#  'coverage': 2730,
#  'available': 1419,
#  'reply': 8415,
#  'asap': 1320,
#  'wrost': 10986,
#  'basis': 1607,
#  'problem': 7887,
#  'pack': 7325,
#  'nikal': 6966,
#  'diya': 3304,
#  'dedo': 2960,
#  'jaye': 5390,
#  'scam': 8850,
#  'shame': 9028,
#  'avg': 1422,
#  'improve': 5029,
#  'port': 7731,
#  'old': 7174,
#  'number': 7073,
#  'uynngjspnm': 10455,
#  'easy': 3478,
#  'feel': 3934,
#  'distant': 3272,
#  'passing': 7432,
#  'lunch': 6133,
#  'coffee': 2421,
#  'lucky': 6124,
#  'benefit': 1699,
#  '\x9f\x99\x8c\x9f\x8f»': 11624,
#  '\x9f¤\x97': 11673,
#  '5sdojf5oxa': 576,
#  'team': 9807,
#  'appreciate': 1240,
#  'tata': 9786,
#  'aig': 1009,
#  'support': 9645,
#  'gaurav': 4270,
#  'incident': 5048,
#  '20200323409': 331,
#  'given': 4338,
#  'prompt': 7936,
#  'followed': 4072,
#  'case': 2132,
#  'appreciated': 1241,
#  '\x9f¥\x82': 11708,
#  'expectation': 3771,
#  'reality': 8242,
#  'holiday': 4749,
#  'haið\x9f\x99\x84\x9f\x99\x84\x9f\x98£': 4551,
#  'kis': 5683,
#  'sath': 8819,
#  'rha': 8549,
#  'aisað\x9f\x98\x82\x9f\x98\x82': 1033,
#  'auswiwauli': 1403,
#  'sir': 9180,
#  'evening': 3708,
#  'dhananjay': 3132,
#  'chauhan': 2252,
#  'bihar': 1763,
#  'raising': 8153,
#  'issue': 5298,
#  'emi': 3562,
#  'loan': 6035,
#  'dhfl': 3146,
#  'difficult': 3188,
#  'give': 4335,
#  'months': 6636,
#  'government': 4400,
#  'finance': 3983,
#  'minister': 6538,
#  'wave': 10757,
#  'current': 2825,
#  'something': 9282,
#  'women': 10913,
#  'really': 8247,
#  'follows': 4075,
#  'schedule': 8862,
#  'morning': 6648,
#  'till': 10005,
#  'midnight': 6488,
#  'engaged': 3615,
#  'homely': 4757,
#  'task': 9779,
#  'happy': 4584,
#  'helping': 4673,
#  'today': 10043,
#  'cooking': 2660,
#  'dinner': 3203,
#  'wife': 10859,
#  'tjj84n7wa2neâ': 10032,
#  'ordered': 7246,
#  'wifi': 10860,
#  'adapter': 901,
#  'useful': 10420,
#  'last': 5856,
#  'saturday': 8825,
#  'yet': 11081,
#  'delivered': 3014,
#  'reached': 8226,
#  'final': 3979,
#  'center': 2166,
#  'help': 4669,
#  'getting': 4299,
#  'early': 3462,
#  'point': 7693,
#  'basically': 1605,
#  'also': 1098,
#  'bcz': 1633,
#  'problematic': 7888,
#  'anyways': 1205,
#  'reported': 8418,
#  'doctors': 3323,
#  'viral': 10603,
#  'letters': 5940,
#  'nitish': 6984,
#  'kumar': 5768,
#  'nmch': 6992,
#  '36750â': 437,
#  'never': 6926,
#  'felt': 3943,
#  '\x9f\x99\x81': 11610,
#  'pls': 7665,
#  'district': 3285,
#  'hospital': 4820,
#  'dewas': 3122,
#  'sanitizer': 8793,
#  'kit': 5689,
#  'guide': 4484,
#  'staff': 9405,
#  'class': 2358,
#  'comes': 2454,
#  'hygine': 4921,
#  'nurses': 7079,
#  'safai': 8719,
#  'sindh': 9164,
#  'approved': 1251,
#  'purchase': 8013,
#  '290': 381,
#  'ventilators': 10544,
#  'million': 6516,
#  'items': 5310,
#  'ppe': 7770,
#  'portable': 7732,
#  'ray': 8215,
#  'machines': 6171,
#  '100': 35,
#  'rapid': 8197,
#  'antigen': 1190,
#  'test': 9877,
#  'used': 10418,
#  'china': 2297,
#  'deal': 2926,
#  'well': 10806,
#  'tmhskjso1k': 10039,
#  'nenaikkere': 6908,
#  'worries': 10952,
#  'asâ': 1362,
#  'solution': 9274,
#  'communication': 2480,
#  'unlimited': 10353,
#  'messaging': 6462,
#  'scheduling': 8863,
#  'chat': 2249,
#  'search': 8899,
#  'app': 1221,
#  'capabilities': 2092,
#  'jhbvn0kkf8': 5406,
#  'tips': 10020,
#  'elders': 3533,
#  'spending': 9349,
#  'lock': 6047,
#  'kinda': 5674,
#  'life': 5964,
#  'closed': 2387,
#  'room': 8632,
#  'years': 11072,
#  '\x9f¤\x94': 11669,
#  'maharashtra': 6203,
#  'govt': 4407,
#  'decided': 2945,
#  'vegetables': 10529,
#  'fruits': 4170,
#  'grocery': 4450,
#  'bakery': 1521,
#  'exempted': 3751,
#  'vendors': 10540,
#  'deliveries': 3016,
#  'taking': 9750,
#  'appropriate': 1248,
#  'care': 2109,
#  'police': 7698,
#  'facilitate': 3841,
#  'movment': 6678,
#  'road': 8606,
#  'restriction': 8503,
#  'movement': 6673,
#  'friend': 4154,
#  'left': 5913,
#  'abbottabad': 812,
#  'contain': 2618,
#  'usa': 10412,
#  'could': 2706,
#  'contained': 2619,
#  'dear': 2931,
#  'avneesh': 1427,
#  'tiwari': 10030,
#  'pratapgarh': 7791,
#  'uttarpradesh': 10448,
#  'currently': 2826,
#  'varanasi': 10505,
#  'unable': 10289,
#  'town': 10094,
#  'bike': 1767,
#  'department': 3044,
#  'allow': 1078,
#  'reach': 8224,
#  'homeð\x9f\x99\x8f\x9f\x99\x8f': 4793,
#  'muna': 6721,
#  'kami': 5527,
#  '\x9f\x9a¨': 11658,
#  '\x9f\x98\x82\x9f\x98\x82work': 11521,
#  'uniform': 10327,
#  'kadam': 5504,
#  'behram': 1676,
#  'baug': 1621,
#  'jogeshwari': 5434,
#  'west': 10813,
#  'mumbai': 6719,
#  '400102': 471,
#  'come': 2451,
#  'strict': 9521,
#  'action': 883,
#  'anything': 1202,
#  'seriously': 8979,
#  'seems': 8932,
#  'paridhabangal': 7396,
#  'pesuiyyqbb': 7541,
#  'power': 7765,
#  'supply': 9643,
#  'interrupt': 5232,
#  'netaji': 6919,
#  'pac': 7323,
#  'audioconferencing': 1394,
#  'chief': 2288,
#  'secretary': 8912,
#  'dgp': 3124,
#  'secretaries': 8911,
#  'collectors': 2440,
#  'regional': 8318,
#  'adminstrators': 932,
#  'reviewed': 8536,
#  'planned': 7631,
#  'ahead': 997,
#  'repeat': 8407,
#  'message': 6460,
#  'planning': 7632,
#  'delivery': 3018,
#  'understanding': 10308,
#  'abiding': 822,
#  'fky2tra2cp': 4021,
#  'complete': 2508,
#  'going': 4368,
#  'stitching': 9479,
#  'meeting': 6426,
#  'friends': 4156,
#  'continues': 2632,
#  'bit': 1784,
#  'making': 6236,
#  'masks': 6354,
#  'qupnsxivwf': 8107,
#  'saab': 8703,
#  'udh': 10261,
#  'forum': 4112,
#  'yeah': 11070,
#  'look': 6076,
#  'pnb': 7679,
#  'customers': 2835,
#  '\x9f¤£\x9f¤£': 11685,
#  'omjg7hscqf': 7186,
#  'family': 3876,
#  'alsl': 1097,
#  'lot': 6094,
#  'countries': 2715,
#  'arw': 1315,
#  'kept': 5603,
#  'isolation': 5295,
#  'rikshwa': 8572,
#  'wala': 10709,
#  'foods': 4081,
#  'tell': 9841,
#  'since': 9162,
#  'someway': 9286,
#  'social': 9258,
#  'distancing': 3270,
#  'mind': 6520,
#  'online': 7198,
#  'survey': 9676,
#  'form': 4105,
#  'usp': 10426,
#  'send': 8956,
#  'twtâ': 10234,
#  'means': 6401,
#  'total': 10079,
#  'data': 2899,
#  '2gb': 392,
#  '5gb': 560,
#  'two': 10232,
#  'finished': 3994,
#  'showing': 9106,
#  'exhausted': 3756,
#  'attached': 1371,
#  'screenshot': 8884,
#  'arr74oxxbq': 1289,
#  'year': 11071,
#  'kid': 5659,
#  'stuck': 9542,
#  'patna': 7451,
#  'law': 5876,
#  'house': 4843,
#  'self': 8945,
#  'weeks': 10796,
#  'bring': 1944,
#  'jamshedpur': 5369,
#  'important': 5019,
#  'historical': 4727,
#  'announcement': 1173,
#  'made': 6176,
#  'hon': 4795,
#  'narendra': 6818,
#  'modiji': 6604,
#  'fight': 3961,
#  'mahamari': 6199,
#  'covid19': 2736,
#  'lockfown': 6056,
#  'distence': 3274,
#  'volenteryl': 10650,
#  'leader': 5892,
#  'lauds': 5867,
#  'modi': 6602,
#  'measures': 6406,
#  'combat': 2449,
#  'htmlâ': 4868,
#  'namo': 6805,
#  '0erxi0fcmu': 19,
#  'man': 6259,
#  '\x9f\x98\x80\x9f\x98\x80': 11513,
#  'indian': 5075,
#  '\x9f\x92\x9f\x92': 11466,
#  'surgical': 9666,
#  'strike': 9526,
#  'indiansð\x9f\x87®\x9f\x87': 5077,
#  'relegation': 8358,
#  'meetings': 6427,
#  '\x9f\x99\x8f': 11625,
#  '¸\x84¸·¸\xad¸\xad¸°\x84¸£': 11829,
#  '\x83¸\x99\x80¸¡¸·\x88¸\xad': 11282,
#  '\x83¼19': 11284,
#  '\x80¸£¸¸¸¹à¹\x89': 11266,
#  'staying': 9452,
#  'cant': 2089,
#  'fit': 4008,
#  'workout': 10935,
#  'importantly': 5020,
#  'guscw02mpf': 4508,
#  'r78fyg2nu64dâ': 8115,
#  'mha': 6479,
#  'guidelines': 4487,
#  'study': 9551,
#  'wfh': 10818,
#  'affected': 968,
#  'recvd': 8287,
#  'forward': 4113,
#  'true': 10186,
#  'letâ\x80\x99': 5942,
#  'design': 3075,
#  'economic': 3490,
#  'ecosystem': 3493,
#  'planet': 7630,
#  'earth': 3469,
#  'might': 6491,
#  'saved': 8833,
#  'sh3gzie5mx': 9013,
#  'little': 6017,
#  'boring': 1876,
#  'saftey': 8734,
#  'others': 7272,
#  '10cxttqwad': 59,
#  'alamgari': 1049,
#  'bazar': 1624,
#  'stamping': 9414,
#  'thousands': 9968,
#  'citizens': 2345,
#  'indelible': 5069,
#  'ink': 5144,
#  'posting': 7747,
#  'notices': 7031,
#  'tracing': 10105,
#  'violators': 10599,
#  'spoke': 9366,
#  'intl': 5240,
#  'fliers': 4040,
#  'landed': 5832,
#  'bengaluru': 1704,
#  'dept': 3060,
#  'dealing': 2930,
#  'foreign': 4095,
#  'returnees': 8523,
#  'karnataka': 5556,
#  'tracking': 10107,
#  'returneesâ': 8524,
#  'represent': 8425,
#  'speak': 9332,
#  'kids': 5663,
#  'damn': 2882,
#  'rest': 8491,
#  'arenâ\x80\x99': 1273,
#  'studies': 9548,
#  'low': 6108,
#  'bangalore': 1560,
#  'h1gxuu06ggjâ': 4528,
#  'taxing': 9795,
#  'phewwwwwww': 7563,
#  'society': 9259,
#  'girl': 4333,
#  'another': 1179,
#  'london': 6071,
#  'britain': 1948,
#  'bunglows': 1996,
#  'side': 9133,
#  'front': 4165,
#  'raat': 8119,
#  'nindiya': 6977,
#  'haram': 4585,
#  'kar': 5541,
#  'inho': 5134,
#  '\x9f\x98\x9e': 11581,
#  'taxes': 9794,
#  'essentaials': 3689,
#  'medicine': 6416,
#  'recover': 8279,
#  'pointing': 7695,
#  'saying': 8844,
#  'correct': 2693,
#  'talking': 9755,
#  'blame': 1796,
#  'game': 4232,
#  'else': 3551,
#  'safely': 8724,
#  'newsalert': 6932,
#  'greater': 4440,
#  'resident': 8453,
#  'discharged': 3224,
#  'gims': 4326,
#  'successfully': 9583,
#  'treated': 10156,
#  'tests': 9881,
#  'came': 2072,
#  'negative': 6893,
#  'confirms': 2559,
#  'recovery': 8282,
#  'patient': 7447,
#  'says': 8845,
#  'director': 3212,
#  'brig': 1941,
#  'rakesh': 8169,
#  'gupta': 4498,
#  'okbaecnsnb': 7169,
#  'safeguard': 8723,
#  'coronavirusð\x9f\x98·': 2686,
#  '\x8c§': 11292,
#  '§\x84\x84\x81': 11800,
#  '±\x81': 11820,
#  '\x9f\x98': 11511,
#  'tldjspa3m9': 10036,
#  'fun': 4185,
#  'play': 7646,
#  'josh': 5454,
#  'got': 4393,
#  'everything': 3720,
#  'phupho': 7578,
#  'prevention': 7853,
#  'epidemic': 3660,
#  'fpplmjnysr': 4126,
#  'create': 2752,
#  'positivity': 7741,
#  'around': 1288,
#  'diverting': 3296,
#  'sharing': 9043,
#  'enjoy': 3626,
#  'even': 3707,
#  'raise': 8150,
#  'voice': 10647,
#  'ourseleves': 7280,
#  'donate': 3341,
#  'retweet': 8527,
#  'realise': 8240,
#  'roots': 8637,
#  'breathing': 1936,
#  'values': 10497,
#  'value': 10495,
#  'chance': 2221,
#  'quality': 8078,
#  'surat': 9655,
#  'information': 5126,
#  'city': 2346,
#  'near': 6868,
#  'goenka': 4364,
#  'international': 5226,
#  'school': 8867,
#  'foreigner': 4096,
#  'living': 6026,
#  'among': 1133,
#  'noð\x9f\x91\x87': 7049,
#  'itâ\x80\x99': 5319,
#  'serving': 8991,
#  'requires': 8441,
#  'maintain': 6223,
#  'structured': 9538,
#  'routine': 8644,
#  'r8kdom4tl9': 8117,
#  'sonia': 9297,
#  'gandhi': 4235,
#  'rahul': 8140,
#  'robert': 8613,
#  'vadra': 10480,
#  'start': 9423,
#  'distributing': 3281,
#  'accumulated': 862,
#  'wealth': 10770,
#  'poor': 7718,
#  'charity': 2246,
#  'begins': 1665,
#  'banglow': 1566,
#  'occupied': 7124,
#  'spared': 9330,
#  'ward': 10728,
#  'patients': 7448,
#  'convey': 2652,
#  'perfect': 7510,
#  'opportunity': 7228,
#  'earn': 3463,
#  'join': 5441,
#  'contact': 2614,
#  '6w7q9ehkn5': 616,
#  'isnâ\x80\x99': 5290,
#  'affecting': 969,
#  'graphic': 4432,
#  'designing': 3078,
#  'branding': 1915,
#  'timely': 10010,
#  'guaranteed': 4474,
#  '\x9f\x98\x83\x9f\x98\x8a': 11535,
#  'better': 1716,
#  'productive': 7905,
#  'rather': 8205,
#  'goers': 4365,
#  'panicking': 7374,
#  'productivity': 7908,
#  'digital': 3193,
#  'nomadsâ\x80¦': 7008,
#  'y5zg2c25tgu2â': 11050,
#  'implementing': 5016,
#  'section': 8915,
#  '144': 114,
#  'roaming': 8610,
#  'colaba': 2427,
#  'market': 6328,
#  'without': 10892,
#  'precautions': 7806,
#  'strong': 9531,
#  'reason': 8250,
#  'moment': 6616,
#  'van': 10499,
#  'goes': 4366,
#  'patrolling': 7453,
#  'imjetilyy3': 4997,
#  'addressed': 914,
#  'honorable': 4803,
#  'required': 8438,
#  'teleperformance': 9834,
#  'management': 6263,
#  'giving': 4341,
#  'gyan': 4520,
#  'balcony': 1535,
#  'star': 9420,
#  'managing': 6267,
#  '130': 102,
#  'dare': 2893,
#  'manage': 6261,
#  'ground': 4451,
#  'enforce': 3612,
#  'elitist': 3548,
#  'gang': 4237,
#  'vip': 10602,
#  'privileges': 7880,
#  'aside': 1328,
#  'full': 4183,
#  'die': 3173,
#  'professional': 7912,
#  'lose': 6089,
#  'job': 5431,
#  'deliver': 3010,
#  ...}

# %%
# example of vectorized text
sample_tweet = df_lockdown['tweet'][10]
print(sample_tweet)
print('\n')
# vector representation
bow_sample = bow_transformer.transform([sample_tweet])
print(bow_sample)
print('\n')
# Out:
# mohalla clinic doctor from mohanpuri maujpur area gopal jha found request all those who visited there between 12th march 18th march follow home quarantine for days pic twitter com xouum13ekv
#
#
#   (0, 100)	1
#   (0, 166)	1
#   (0, 1271)	1
#   (0, 2381)	1
#   (0, 2448)	1
#   (0, 2912)	1
#   (0, 3322)	1
#   (0, 4071)	1
#   (0, 4116)	1
#   (0, 4385)	1
#   (0, 4752)	1
#   (0, 5401)	1
#   (0, 6314)	2
#   (0, 6378)	1
#   (0, 6606)	1
#   (0, 6610)	1
#   (0, 7584)	1
#   (0, 8079)	1
#   (0, 8432)	1
#   (0, 10230)	1
#   (0, 10623)	1
#   (0, 11029)	1

# %%
messages_bow = bow_transformer.transform(df_lockdown['tweet'])

# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', messages_bow.shape)
print('Amount of Non-Zero occurences: ', messages_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (3515, 11870)
# Amount of Non-Zero occurences:  61150

# %%
# run predictions on twitter data
tweet_preds = model_NB.predict(df_lockdown['tweet'])

# append predictions to dataframe
df_tweet_preds = df_lockdown.copy()
df_tweet_preds['predictions'] = tweet_preds
df_tweet_preds.shape
# Out:
# (3515, 36)

# %%
# print text and sentiment

index = random.sample(range(tweet_preds.shape[0]), 20)
for text, sentiment in zip(df_tweet_preds.tweet[index],
                           df_tweet_preds.predictions[index]):
    print (sentiment, '--', text, '\n')
# Out:
# 0 -- yea have gone through your video and post that finalising 55â uhd can you confirm this has memc and want purchase now from where can get this delivered home this lockdown not working
#
# 0 -- although you have work from home but you donâ forget find some delicious food eat pic twitter com xsyeljjflr
#
# 0 -- worried about post lockdown problems your workplace career only solution upgrade your skills now stay ahead time stay home learn desired skills only from cadd centre new batches from 13th april call 8518832525 9755597955 pic twitter com b4txh7emxh
#
# 0 -- still facing internet connectivity issue please help resolve issue cannot work from home
#
# 0 -- bananas your pyjamas while you canâ get your favourite dessert from the market hereâ something very easy make home while your pyjamas  @ delhi india igshid rig4t516bzjrâ ¦
#
# 0 -- when its sunday you can play district cricket league nor chennai non division league practicing defence from home balcony practice what you lack during this quarantine time perfectâ¦ igshid 15vci818ffhbwâ ¦
#
# 0 -- gong zuojiong director the infectious diseases department wuhan hospitals explained how they battled covid wuhan widespread testing isolating even mild cases away from home prevent cross infection within families twitter impression trueâ ¦
#
# 0 -- from gujarat
# coming for tours tamilnadu now all india lockdown have wheeler already
# please permit back home with medical report contact 9725841399
#
# 0 -- while evacuated indian are taken quarantine area from flight these poor are ridiculed they take milk tanker containers reach home these containers are stopped and drivers booked air india pilots get appreciated may queen marry ask why don use plane
#
# 0 -- people are home lockdown and prices daily essential need becoming higher how the people will survive poor ppl will die from hunger then covid kindly take some necessary action
#
# 0 -- why not make this super costly 4500â corona test reimbursable that morw and more ppl their own from home this will resuce burden govt machinery too can upload info based adhaar govt
#
# 0 -- team jio delivery jiofi device and sim card available during lockdown want one for working from home tried from your website but says delivery not available location gaur city noida
#
# 0 -- could please allow way airtel fix the problem there are many people area struggling due bad network please consider this request many people working from home
#
# 0 -- work from home ¦ igshid fuws9ywq20â ¦
#
# 0 -- double tab ¥¸ you want dream life stay home but fully dedicated about team dreams are work from home stay home any burden always positive this world always full withâ¦ igshid gzkymgqkid0eâ ¦
#
# 0 -- allah miyan pls end this quarantine  office time and never wish work from home again pls pls pls pic twitter com z7s2lzcbje
#
# 0 -- this speaks for itself work from home @ max events dubai igshid 1kud708vctt99â ¦
#
# 0 -- happy share that completed day home quarantine without any symptoms since return from march not easy self isolate but learned some good hygiene routines
#
# 0 -- make work from home standard feature encourage corporates adopt permanently bring mechanism universal basic income once itâ implemented poor wonâ suffer whenever there disruption that takes away their livelihood
#
# 0 -- covid dictionary weekend noun part the week when you either work for homeâ work from homeâ

# %%
pos =  df_tweet_preds['predictions']==1
neg =  df_tweet_preds['predictions']==-1
neu =  df_tweet_preds['predictions']==0

# %%
positive = df_tweet_preds[pos]
nega = df_tweet_preds[neg]
neut = df_tweet_preds[neu]

# %%
positive
# Out:
#       Unnamed: 0                   id      conversation_id     created_at  \
# 94            94  1242814919608684544  1242814919608684544  1585145141000
# 266          266  1243162821610713088  1242752514199441413  1585228088000
# 363          363  1243593887207301122  1243593887207301122  1585330862000
# 365          365  1243591061227831296  1243591061227831296  1585330188000
# 512          512  1243461425084928000  1243461425084928000  1585299280000
# 546          546  1243947687562665984  1243947687562665984  1585415214000
# 622          622  1243877394315792386  1243877394315792386  1585398455000
# 728          728  1244299594780966912  1244299594780966912  1585499116000
# 873          873  1244121827238006785  1244121547213701121  1585456732000
# 1126        1126  1244964996527747073  1244964996527747073  1585657760000
# 1146        1146  1244939821610496001  1244936223321231362  1585651757000
# 1266        1266  1245365364159942657  1245365364159942657  1585753215000
# 1374        1374  1245163287060283392  1245163287060283392  1585705036000
# 1491        1491  1245607252028846080  1245607252028846080  1585810885000
# 1756        1756  1246417228628557824  1246417228628557824  1586003999000
# 1792        1792  1246342535624167425  1246342535624167425  1585986191000
# 1980        1980  1247188046178439169  1247188046178439169  1586187776000
# 1995        1995  1247163375399755776  1247163375399755776  1586181894000
# 2172        2172  1247420770931728386  1247362143059501058  1586243262000
# 2211        2211  1247362304527626241  1247362304527626241  1586229322000
# 2247        2247  1247913310239870976  1247913310239870976  1586360692000
# 2364        2364  1247699438706909184  1247505273285152768  1586309701000
# 2368        2368  1247689458796748800  1247689458796748800  1586307322000
# 2395        2395  1248275528580100098  1248275528580100098  1586447052000
# 2489        2489  1248132880057774080  1248132880057774080  1586413042000
# 2615        2615  1248496285490929664  1248494478949617664  1586499685000
# 2693        2693  1248957160135905284  1248957160135905284  1586609566000
# 2775        2775  1248817856990466048  1248817856990466048  1586576353000
# 2797        2797  1249377390687670273  1249377390687670273  1586709756000
# 2828        2828  1249329764822691841  1249329764822691841  1586698402000
# 2838        2838  1249320279131795457  1249320279131795457  1586696140000
# 2849        2849  1249302870391836673  1249215086348165121  1586691989000
# 2907        2907  1249208039548375045  1249005013533245440  1586669380000
# 2916        2916  1249183985500147712  1249183985500147712  1586663645000
# 3015        3015  1249590737647394817  1249590737647394817  1586760622000
# 3054        3054  1249518338977304576  1249518338977304576  1586743361000
# 3093        3093  1250079167351156736  1250022660559396865  1586877073000
# 3117        3117  1250044429131337728  1249775847298326528  1586868791000
# 3125        3125  1250029788493946881  1250029788493946881  1586865300000
# 3243        3243  1250422605305151488  1250342100081577986  1586958955000
# 3254        3254  1250409946212110337  1250409946212110337  1586955937000
# 3262        3262  1250398018949599232  1250398018949599232  1586953093000
# 3354        3354  1250273362829402115  1249788919463522304  1586923373000
# 3357        3357  1250270798054453250  1250267083083927559  1586922761000
# 3426        3426  1250753257879699456  1250678624723714049  1587037789000
# 3455        3455  1250687549330210818  1250687549330210818  1587022123000
# 3471        3471  1250650397494124545  1250650397494124545  1587013265000
# 3566        3566  1251054459616219136  1251054459616219136  1587109601000
# 3571        3571  1251041455679963136  1251041455679963136  1587106500000
# 3594        3594  1251014907644035072  1251014907644035072  1587100171000
#
#                      date  timezone        place  \
# 94    2020-03-25 19:35:41       530          NaN
# 266   2020-03-26 18:38:08       530          NaN
# 363   2020-03-27 23:11:02       530          NaN
# 365   2020-03-27 22:59:48       530      Gaighat
# 512   2020-03-27 14:24:40       530          NaN
# 546   2020-03-28 22:36:54       530          NaN
# 622   2020-03-28 17:57:35       530          NaN
# 728   2020-03-29 21:55:16       530          NaN
# 873   2020-03-29 10:08:52       530          NaN
# 1126  2020-03-31 17:59:20       530          NaN
# 1146  2020-03-31 16:19:17       530          NaN
# 1266  2020-04-01 20:30:15       530          NaN
# 1374  2020-04-01 07:07:16       530          NaN
# 1491  2020-04-02 12:31:25       530          NaN
# 1756  2020-04-04 18:09:59       530  Vyas colony
# 1792  2020-04-04 13:13:11       530          NaN
# 1980  2020-04-06 21:12:56       530          NaN
# 1995  2020-04-06 19:34:54       530          NaN
# 2172  2020-04-07 12:37:42       530          NaN
# 2211  2020-04-07 08:45:22       530          NaN
# 2247  2020-04-08 21:14:52       530          NaN
# 2364  2020-04-08 07:05:01       530          NaN
# 2368  2020-04-08 06:25:22       530          NaN
# 2395  2020-04-09 21:14:12       530          NaN
# 2489  2020-04-09 11:47:22       530          NaN
# 2615  2020-04-10 11:51:25       530          NaN
# 2693  2020-04-11 18:22:46       530          NaN
# 2775  2020-04-11 09:09:13       530          NaN
# 2797  2020-04-12 22:12:36       530          NaN
# 2828  2020-04-12 19:03:22       530          NaN
# 2838  2020-04-12 18:25:40       530          NaN
# 2849  2020-04-12 17:16:29       530          NaN
# 2907  2020-04-12 10:59:40       530          NaN
# 2916  2020-04-12 09:24:05       530          NaN
# 3015  2020-04-13 12:20:22       530          NaN
# 3054  2020-04-13 07:32:41       530          NaN
# 3093  2020-04-14 20:41:13       530          NaN
# 3117  2020-04-14 18:23:11       530          NaN
# 3125  2020-04-14 17:25:00       530          NaN
# 3243  2020-04-15 19:25:55       530          NaN
# 3254  2020-04-15 18:35:37       530          NaN
# 3262  2020-04-15 17:48:13       530          NaN
# 3354  2020-04-15 09:32:53       530          NaN
# 3357  2020-04-15 09:22:41       530          NaN
# 3426  2020-04-16 17:19:49       530          NaN
# 3455  2020-04-16 12:58:43       530          NaN
# 3471  2020-04-16 10:31:05       530          NaN
# 3566  2020-04-17 13:16:41       530          NaN
# 3571  2020-04-17 12:25:00       530          NaN
# 3594  2020-04-17 10:39:31       530          NaN
#
#                                                   tweet  \
# 94    during lockdown lets create positivity around ...
# 266   happy navratri you enjoy work from home this n...
# 363   our team brave soldiers working field for the ...
# 365   safe your home safe from covid ¥¸¥¸¥¸ ...
# 512   day sprout @ bopal ahmedabad gujrat igshid 1an...
# 546   letâ see whatâsgoingon with unique live fr...
# 622   working from home how more productive and posi...
# 728   nice atmosphere here and the day here world bi...
# 873                             good job work from home
# 1126  thank you mtnl appreciate all the efforts rest...
# 1146  glad that our friends from america are back ho...
# 1266  mashed this beautiful song sung arijitsingh na...
# 1374  everyone untill the real fool step out from ho...
# 1491                             this song dedicated ¦
# 1756  enjoying work from home with relaince jio giga...
# 1792  best can take from @ jodhpur igshid 16d3sat7ph...
# 1980  this great course with official certification ...
# 1995  you are more productive after working from hom...
# 2172  must say work for homeâ more appropriate t...
# 2211                     wow good one work from home ¦
# 2247  please accept sincere thanks for the outstandi...
# 2364  nice efforts give thoughtful message work from...
# 2368  rahul will wait itâ difficult work from home...
# 2395  covid special edition from home now lhtq9qieao...
# 2489  this present scenario apart from having good t...
# 2615   good work from home and best supporting everyone
# 2693  this not all inspiring she risking her baby th...
# 2775  good morning bangladesh hope that one day our ...
# 2797  dinner tonight looks pretty good great day and...
# 2828  stay home safe life distance mantaining minimi...
# 2838  follow below instructions are very strictly be...
# 2849  @ mam quarantine work from home  look...
# 2907  mam great see you home during this quarantine ...
# 2916  happy easter 2020 nepal sanctuary treks wishes...
# 3015  how are you friends how your home quarantine d...
# 3054  happy baisakhi everyone stay safe and protect ...
# 3093    stay home\nkeep safe yourself from coronavirus
# 3117  that really nice job from kanthi panchayat sho...
# 3125  neither will you come out home nor will away w...
# 3243   busy  helping out with home duties every n...
# 3254  from our awesome home perfect for @ eklavya mo...
# 3262  how true what ceoâ and ctoâ couldnâ covi...
# 3354  youâ doing great job  one your admirer...
# 3357  intervention lol from delhi riots during cab c...
# 3426  yes kannan absolutely doing amazing job resign...
# 3455  great job act team appreciate your help this s...
# 3471  big salute ghaziabad police for the good job s...
# 3566  spread kindness little help from ¦ igshid djh...
# 3571  while are lockdown thought why not appreciate ...
# 3594  hey young lady hope you your family are doing ...
#
#                                                hashtags cashtags  ...  \
# 94                                                   []       []  ...
# 266                                                  []       []  ...
# 363                                                  []       []  ...
# 365                                           ['#stay']       []  ...
# 512   ['#covid_19', '#covidcooking', '#workfromhome'...       []  ...
# 546   ['#contentgetssmarter', '#sportsforeveryone', ...       []  ...
# 622   ['#worklifeindia', '#covid', '#indiafightscovi...       []  ...
# 728   ['#wankhede', '#ipl2020', '#mi', '#csk', '#roh...       []  ...
# 873                                                  []       []  ...
# 1126  ['#indiafightscorona', '#mtnl', '#coronahaareg...       []  ...
# 1146                                                 []       []  ...
# 1266     ['#shanghai', '#duaa', '#corona', '#lockdown']       []  ...
# 1374  ['#fool', '#stayathome', '#staysafe', '#corona...       []  ...
# 1491                                                 []       []  ...
# 1756                                                 []       []  ...
# 1792  ['#sunset', '#home', '#corona', '#workfromhome...       []  ...
# 1980  ['#onlinelearning', '#onlineclasses', '#corona...       []  ...
# 1995                                                 []       []  ...
# 2172                                                 []       []  ...
# 2211                                                 []       []  ...
# 2247                                                 []       []  ...
# 2364                                                 []       []  ...
# 2368                                                 []       []  ...
# 2395   ['#toughtalk', '#live', '#toughtalktapainsanga']       []  ...
# 2489  ['#lockdown', '#stayhomeindia', '#coronavirus'...       []  ...
# 2615                                                 []       []  ...
# 2693                                                 []       []  ...
# 2775                                                 []       []  ...
# 2797     ['#wfh', '#lol', '#great', '#relax', '#enjoy']       []  ...
# 2828                                                 []       []  ...
# 2838  ['#covid_19', '#stay', '#home', '#staysafe', '...       []  ...
# 2849                                                 []       []  ...
# 2907  ['#bengal', '#bengalfightscorona', '#stayhome'...       []  ...
# 2916                                      ['#stayhome']       []  ...
# 3015                                                 []       []  ...
# 3054                                                 []       []  ...
# 3093                                  ['#chinesevirus']       []  ...
# 3117  ['#covid_19', '#stay', '#home', '#stay', '#safe']       []  ...
# 3125                     ['#covid2019', '#coronavirus']       []  ...
# 3243                                                 []       []  ...
# 3254  ['#wholewheet', '#bun', '#otg', '#breads', '#b...       []  ...
# 3262  ['#covid2019', '#covid', '#covid19', '#covÄ±d19']       []  ...
# 3354                                                 []       []  ...
# 3357                                                 []       []  ...
# 3426                                                 []       []  ...
# 3455  ['#lockdownindia', '#indiafightscorona', '#fro...       []  ...
# 3471                                                 []       []  ...
# 3566  ['#healthyathome', '#stay_home_stay_safe', '#s...       []  ...
# 3571                                  ['#homefoodpune']       []  ...
# 3594        ['#motivation', '#covid_19', '#stayathome']       []  ...
#
#       user_rt_id  user_rt retweet_id  \
# 94           NaN      NaN        NaN
# 266          NaN      NaN        NaN
# 363          NaN      NaN        NaN
# 365          NaN      NaN        NaN
# 512          NaN      NaN        NaN
# 546          NaN      NaN        NaN
# 622          NaN      NaN        NaN
# 728          NaN      NaN        NaN
# 873          NaN      NaN        NaN
# 1126         NaN      NaN        NaN
# 1146         NaN      NaN        NaN
# 1266         NaN      NaN        NaN
# 1374         NaN      NaN        NaN
# 1491         NaN      NaN        NaN
# 1756         NaN      NaN        NaN
# 1792         NaN      NaN        NaN
# 1980         NaN      NaN        NaN
# 1995         NaN      NaN        NaN
# 2172         NaN      NaN        NaN
# 2211         NaN      NaN        NaN
# 2247         NaN      NaN        NaN
# 2364         NaN      NaN        NaN
# 2368         NaN      NaN        NaN
# 2395         NaN      NaN        NaN
# 2489         NaN      NaN        NaN
# 2615         NaN      NaN        NaN
# 2693         NaN      NaN        NaN
# 2775         NaN      NaN        NaN
# 2797         NaN      NaN        NaN
# 2828         NaN      NaN        NaN
# 2838         NaN      NaN        NaN
# 2849         NaN      NaN        NaN
# 2907         NaN      NaN        NaN
# 2916         NaN      NaN        NaN
# 3015         NaN      NaN        NaN
# 3054         NaN      NaN        NaN
# 3093         NaN      NaN        NaN
# 3117         NaN      NaN        NaN
# 3125         NaN      NaN        NaN
# 3243         NaN      NaN        NaN
# 3254         NaN      NaN        NaN
# 3262         NaN      NaN        NaN
# 3354         NaN      NaN        NaN
# 3357         NaN      NaN        NaN
# 3426         NaN      NaN        NaN
# 3455         NaN      NaN        NaN
# 3471         NaN      NaN        NaN
# 3566         NaN      NaN        NaN
# 3571         NaN      NaN        NaN
# 3594         NaN      NaN        NaN
#
#                                                reply_to  retweet_date  \
# 94    [{'user_id': '2877019866', 'username': 'Poorni...           NaN
# 266   [{'user_id': '1098659864174362624', 'username'...           NaN
# 363   [{'user_id': '882552800231673857', 'username':...           NaN
# 365   [{'user_id': '1243581942483877888', 'username'...           NaN
# 512   [{'user_id': '301353134', 'username': 'Gohil_H...           NaN
# 546   [{'user_id': '2431400787', 'username': 'ImSoha...           NaN
# 622   [{'user_id': '17705993', 'username': 'devinagu...           NaN
# 728   [{'user_id': '1085393636265730049', 'username'...           NaN
# 873   [{'user_id': '847669140366123008', 'username':...           NaN
# 1126  [{'user_id': '955987006626156544', 'username':...           NaN
# 1146  [{'user_id': '281023435', 'username': 'NirajNP...           NaN
# 1266  [{'user_id': '37156814', 'username': 'djanoopa...           NaN
# 1374  [{'user_id': '790869804244541441', 'username':...           NaN
# 1491  [{'user_id': '941703703500800000', 'username':...           NaN
# 1756  [{'user_id': '1179060175694467072', 'username'...           NaN
# 1792  [{'user_id': '270316462', 'username': 'mukeshg...           NaN
# 1980  [{'user_id': '3240321962', 'username': 'richar...           NaN
# 1995  [{'user_id': '750718725028876288', 'username':...           NaN
# 2172  [{'user_id': '1144712011', 'username': 'PencyS...           NaN
# 2211  [{'user_id': '330527581', 'username': 'gani178...           NaN
# 2247  [{'user_id': '1243814267234570241', 'username'...           NaN
# 2364  [{'user_id': '921662262682644481', 'username':...           NaN
# 2368  [{'user_id': '169786869', 'username': 'sam3847'}]           NaN
# 2395  [{'user_id': '358016479', 'username': 'DilBhus...           NaN
# 2489  [{'user_id': '615057396', 'username': 'bidisha...           NaN
# 2615  [{'user_id': '1099659966896586752', 'username'...           NaN
# 2693  [{'user_id': '142725906', 'username': 'chetan0...           NaN
# 2775  [{'user_id': '776391942598832129', 'username':...           NaN
# 2797  [{'user_id': '249971439', 'username': 'PORAMAP...           NaN
# 2828  [{'user_id': '1017222021472706560', 'username'...           NaN
# 2838  [{'user_id': '1239587066352148481', 'username'...           NaN
# 2849  [{'user_id': '580770092', 'username': 'shathef...           NaN
# 2907  [{'user_id': '3207762963', 'username': 'SATYAM...           NaN
# 2916  [{'user_id': '190203473', 'username': 'sanctua...           NaN
# 3015  [{'user_id': '1213896884915326976', 'username'...           NaN
# 3054  [{'user_id': '1248963689501224960', 'username'...           NaN
# 3093  [{'user_id': '1003513135', 'username': 'guptsh...           NaN
# 3117  [{'user_id': '1208778541036273667', 'username'...           NaN
# 3125  [{'user_id': '1193420206502232065', 'username'...           NaN
# 3243  [{'user_id': '3749770154', 'username': 'imvai8...           NaN
# 3254  [{'user_id': '60799161', 'username': '_anilbah...           NaN
# 3262  [{'user_id': '995292199213400064', 'username':...           NaN
# 3354  [{'user_id': '1101187475823685632', 'username'...           NaN
# 3357  [{'user_id': '127170211', 'username': 'Murali6...           NaN
# 3426  [{'user_id': '616312805', 'username': 'JPSadas...           NaN
# 3455  [{'user_id': '827657390', 'username': '02Nasr'...           NaN
# 3471  [{'user_id': '967632689988882433', 'username':...           NaN
# 3566  [{'user_id': '1242960862987640833', 'username'...           NaN
# 3571  [{'user_id': '3253443764', 'username': 'FoodPr...           NaN
# 3594  [{'user_id': '538187700', 'username': 'leenacr...           NaN
#
#       translate trans_src  trans_dest  \
# 94          NaN       NaN         NaN
# 266         NaN       NaN         NaN
# 363         NaN       NaN         NaN
# 365         NaN       NaN         NaN
# 512         NaN       NaN         NaN
# 546         NaN       NaN         NaN
# 622         NaN       NaN         NaN
# 728         NaN       NaN         NaN
# 873         NaN       NaN         NaN
# 1126        NaN       NaN         NaN
# 1146        NaN       NaN         NaN
# 1266        NaN       NaN         NaN
# 1374        NaN       NaN         NaN
# 1491        NaN       NaN         NaN
# 1756        NaN       NaN         NaN
# 1792        NaN       NaN         NaN
# 1980        NaN       NaN         NaN
# 1995        NaN       NaN         NaN
# 2172        NaN       NaN         NaN
# 2211        NaN       NaN         NaN
# 2247        NaN       NaN         NaN
# 2364        NaN       NaN         NaN
# 2368        NaN       NaN         NaN
# 2395        NaN       NaN         NaN
# 2489        NaN       NaN         NaN
# 2615        NaN       NaN         NaN
# 2693        NaN       NaN         NaN
# 2775        NaN       NaN         NaN
# 2797        NaN       NaN         NaN
# 2828        NaN       NaN         NaN
# 2838        NaN       NaN         NaN
# 2849        NaN       NaN         NaN
# 2907        NaN       NaN         NaN
# 2916        NaN       NaN         NaN
# 3015        NaN       NaN         NaN
# 3054        NaN       NaN         NaN
# 3093        NaN       NaN         NaN
# 3117        NaN       NaN         NaN
# 3125        NaN       NaN         NaN
# 3243        NaN       NaN         NaN
# 3254        NaN       NaN         NaN
# 3262        NaN       NaN         NaN
# 3354        NaN       NaN         NaN
# 3357        NaN       NaN         NaN
# 3426        NaN       NaN         NaN
# 3455        NaN       NaN         NaN
# 3471        NaN       NaN         NaN
# 3566        NaN       NaN         NaN
# 3571        NaN       NaN         NaN
# 3594        NaN       NaN         NaN
#
#                                                  tokens  predictions
# 94    [lockdown, lets, create, positivity, around, d...            1
# 266   [happy, navratri, enjoy, work, home, navratri,...            1
# 363   [team, brave, soldiers, working, field, voicel...            1
# 365   [safe, home, safe, covid, ¥¸¥¸¥¸, , ga...            1
# 512   [day, sprout, bopal, ahmedabad, gujrat, igshid...            1
# 546   [letâ, see, whatâsgoingon, unique, live, h...            1
# 622   [working, home, productive, positive, hereâ,...            1
# 728   [nice, atmosphere, day, world, biggest, cricke...            1
# 873                             [good, job, work, home]            1
# 1126  [thank, mtnl, appreciate, efforts, restoring, ...            1
# 1146  [glad, friends, america, back, home, wish, ple...            1
# 1266  [mashed, beautiful, song, sung, arijitsingh, n...            1
# 1374  [everyone, untill, real, fool, step, home, ¼1...            1
# 1491                              [song, dedicated, ¦]            1
# 1756  [enjoying, work, home, relaince, jio, gigafibe...            1
# 1792  [best, take, jodhpur, igshid, 16d3sat7phq7iâ, ¦]            1
# 1980  [great, course, official, certification, award...            1
# 1995  [productive, working, home, like, productive, ...            1
# 2172  [must, say, work, homeâ, appropriate, wo...            1
# 2211                   [wow, good, one, work, home, ¦]            1
# 2247  [please, accept, sincere, thanks, outstanding,...            1
# 2364  [nice, efforts, give, thoughtful, message, wor...            1
# 2368  [rahul, wait, itâ, difficult, work, home, wi...            1
# 2395  [covid, special, edition, home, lhtq9qieaogâ, ...            1
# 2489  [present, scenario, apart, good, tym, family, ...            1
# 2615     [good, work, home, best, supporting, everyone]            1
# 2693  [inspiring, risking, baby, time, pure, stupid,...            1
# 2775  [good, morning, bangladesh, hope, one, day, co...            1
# 2797  [dinner, tonight, looks, pretty, good, great, ...            1
# 2828  [stay, home, safe, life, distance, mantaining,...            1
# 2838  [follow, instructions, strictly, become, safe,...            1
# 2849  [mam, quarantine, work, home, , looki...            1
# 2907  [mam, great, see, home, quarantine, immense, l...            1
# 2916  [happy, easter, 2020, nepal, sanctuary, treks,...            1
# 3015  [friends, home, quarantine, day, going, good, ...            1
# 3054  [happy, baisakhi, everyone, stay, safe, protec...            1
# 3093              [stay, home, keep, safe, coronavirus]            1
# 3117  [really, nice, job, kanthi, panchayat, coopera...            1
# 3125  [neither, come, home, away, share, share, woul...            1
# 3243  [, busy, , helping, home, duties, every, ...            1
# 3254  [awesome, home, perfect, eklavya, model, resid...            1
# 3262  [true, ceoâ, ctoâ, couldnâ, covid2019, d...            1
# 3354  [youâ, great, job, , one, admirers, in...            1
# 3357  [intervention, lol, delhi, riots, cab, covid, ...            1
# 3426  [yes, kannan, absolutely, amazing, job, resign...            1
# 3455  [great, job, act, team, appreciate, help, situ...            1
# 3471  [big, salute, ghaziabad, police, good, job, st...            1
# 3566  [spread, kindness, little, help, ¦, igshid, d...            1
# 3571  [lockdown, thought, appreciate, talent, home, ...            1
# 3594  [hey, young, lady, hope, family, well, coping,...            1
#
# [50 rows x 36 columns]

# %%
df_tweet_preds.predictions
#pos = df_tweet_preds.predictions.value_counts()[0]
#neg = df_tweet_preds.predictions.value_counts()[1]

#print('Model predictions: Positives - {}, Negatives - {}'.format(neg,pos))
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3610    0
# 3611    0
# 3612    0
# 3613    0
# 3614    0
# Name: predictions, Length: 3515, dtype: int64
